# %% [markdown]
# <a href="https://colab.research.google.com/github/tcjoey/PythonStock/blob/master/%E8%B6%85%E7%B0%A1%E5%96%AE%E5%8F%B0%E8%82%A1%E6%AF%8F%E6%97%A5%E7%88%AC%E8%9F%B2%E6%95%99%E5%AD%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 原文網址：https://www.finlab.tw/超簡單台股每日爬蟲教學

# %%
import requests
from io import StringIO
import pandas as pd
import numpy as np

datestr = '20180131'

# 下載股價
r = requests.post('https://www.twse.com.tw/exchangeReport/MI_INDEX?response=csv&date=' + datestr + '&type=ALL')

# 整理資料，變成表格
df = pd.read_csv(StringIO(r.text.replace("=", "")), 
            header=["證券代號" in l for l in r.text.split("\n")].index(True)-1)

# 整理一些字串：

df.apply(lambda s: pd.to_numeric(s.astype(str).str.replace(",", "").replace("+", "1").replace("-", "-1"), errors='coerce'))
df
# Out:
#          證券代號       證券名稱         成交股數  ... 最後揭示賣量     本益比 Unnamed: 16
# 0        0050     元大台灣50    4,251,739  ...     80    0.00         NaN
# 1        0051    元大中型100        7,500  ...      5    0.00         NaN
# 2        0052       富邦科技        4,001  ...      1    0.00         NaN
# 3        0053       元大電子            1  ...      1    0.00         NaN
# 4        0054     元大台商50        2,001  ...      8    0.00         NaN
# 5        0055   元大MSCI金融       89,001  ...      1    0.00         NaN
# 6        0056      元大高股息    2,438,996  ...     20    0.00         NaN
# 7        0057       富邦摩台            0  ...     20    0.00         NaN
# 8        0058       富邦發達            0  ...     21    0.00         NaN
# 9        0059       富邦金融        2,001  ...      1    0.00         NaN
# 10       0061      元大寶滬深    4,891,073  ...      1    0.00         NaN
# 11     006203   元大MSCI台灣       49,000  ...     20    0.00         NaN
# ...

# %%
df.head()
# Out:
#    證券代號     證券名稱       成交股數   成交筆數  ... 最後揭示賣價 最後揭示賣量   本益比 Unnamed: 16
# 0  0050   元大台灣50  4,251,739  1,176  ...  84.65     80  0.00         NaN
# 1  0051  元大中型100      7,500      3  ...  32.50      5  0.00         NaN
# 2  0052     富邦科技      4,001      5  ...  57.90      1  0.00         NaN
# 3  0053     元大電子          1      1  ...  37.35      1  0.00         NaN
# 4  0054   元大台商50      2,001      3  ...  24.64      8  0.00         NaN
#
# [5 rows x 17 columns]
